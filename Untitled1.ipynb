# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\project\\Project-4-SEMESTER-'

# %%
os.chdir('data')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\project\\Project-4-SEMESTER-\\data'

# %%
df=pd.read_csv('ahl.csv')

# %%
df
# Out:
#     Symbol        Date   Open   High    Low   Close Percent Change     Volume  \
# 0      AHL  2025-12-22  555.0  557.0  545.1  550.20        -1.22 %  12,467.00
# 1      AHL  2025-12-21  565.0  570.0  556.0  557.00        -2.62 %   9,937.00
# 2      AHL  2025-12-18  583.0  583.0  571.3  572.00        -1.41 %   9,929.00
# 3      AHL  2025-12-17  577.1  598.0  577.1  580.20        -1.16 %   7,844.00
# 4      AHL  2025-12-16  595.0  595.0  580.0  587.00        -0.51 %  14,683.00
# ..     ...         ...    ...    ...    ...     ...            ...        ...
# 99     AHL  2025-07-07  607.0  621.0  601.0  604.66        -2.23 %   3,954.00
# 100    AHL  2025-07-06  635.0  660.6  600.0  618.44        -1.22 %   1,230.00
# 101    AHL  2025-07-03  620.0  630.0  607.6  626.09        -0.46 %   4,310.00
# 102    AHL  2025-07-02  624.0  637.3  612.6  629.00         0.67 %   9,594.00
# 103    AHL  2025-07-01  599.0  632.0  599.0  624.81         2.46 %   4,040.00
#
#     Turn Over
# 0           -
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\hp\\Desktop\\project\\Project-4-SEMESTER-'

# %%
file_path=data

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# ...
#   Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# ...
#   Using cached kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# ...
#   Using cached pillow-12.0.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# ...
# Using cached matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
# Using cached contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp314-cp314-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Using cached pillow-12.0.0-cp314-cp314-win_amd64.whl (7.1 MB)
# Using cached pyparsing-3.2.5-py3-none-any.whl (113 kB)
# ...
#
# ...

# %%
df2=pd.read_csv('stock(oct-dec).csv')

# %%
df2
# Out:
#        S.No  Symbol  Conf.      Open      High       Low     Close       LTP  \
# 0         1  ACLBSL      -    930.00    930.00    910.00    911.00    911.00
# 1         1  ACLBSL  26.96    925.00    938.00    923.00    930.00    930.00
# 2         1  ACLBSL  26.96    925.00    938.00    923.00    930.00    930.00
# 3         1  ACLBSL      -    925.00    938.00    923.00    930.00    930.00
# 4         1  ACLBSL      -    949.00    949.00    939.00    939.00    939.00
# ...     ...     ...    ...       ...       ...       ...       ...       ...
# 26296   314    WNLB  38.75  2,110.00  2,114.40  2,080.00  2,100.00  2,100.00
# 26297   314    WNLB  38.75  2,110.00  2,114.40  2,080.00  2,100.00  2,100.00
# 26298   314    WNLB  38.75  2,110.00  2,114.40  2,080.00  2,100.00  2,100.00
# 26299   330   WNLBP      -  1,138.00  1,138.00  1,138.00  1,138.00  1,138.00
# 26300   335   WNLBP      -  1,138.00  1,138.00  1,138.00  1,138.00  1,138.00
#
# ...

# %%
df2.dtypes
# Out:
# S.No               int64
# Symbol            object
# Conf.             object
# Open              object
# High              object
# Low               object
# Close             object
# LTP               object
# Close - LTP      float64
# Close - LTP %    float64
# VWAP              object
# Vol               object
# Prev. Close       object
# Turnover          object
# Trans.            object
# Diff              object
# Range             object
# Diff %           float64
# Range %          float64
# VWAP %           float64
# 120 Days          object
# 180 Days          object
# 52 Weeks High     object
# 52 Weeks Low      object
# date              object
# dtype: object

# %%
          
cols = [
    'Open', 'High', 'Low', 'Close', 'LTP',
    '120 Days', '180 Days',
    '52 Weeks High', '52 Weeks Low',
    'VWAP'
]

for col in cols:
    df2[col] = (
        df2[col]
        .astype(str)                # ensure string
        .str.replace(',', '', regex=False)
        .astype(float)
    )

# %%
df2.dtypes
# Out:
# S.No               int64
# Symbol            object
# Conf.             object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# LTP              float64
# Close - LTP      float64
# Close - LTP %    float64
# VWAP             float64
# Vol               object
# Prev. Close       object
# Turnover          object
# Trans.            object
# Diff              object
# Range             object
# Diff %           float64
# Range %          float64
# VWAP %           float64
# 120 Days         float64
# 180 Days         float64
# 52 Weeks High    float64
# 52 Weeks Low     float64
# date              object
# dtype: object

# %%
col2s = ['Prev. Close', 'Turnover', 'Trans.', 'Diff', 'Range']

for col in col2s:
    df2[col] = (
        df2[col]
        .astype(str)
        .str.replace(',', '', regex=False)
        .astype(float)
    )

# %%
df2.dtypes
# Out:
# S.No               int64
# Symbol            object
# Conf.             object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# LTP              float64
# Close - LTP      float64
# Close - LTP %    float64
# VWAP             float64
# Vol               object
# Prev. Close      float64
# Turnover         float64
# Trans.           float64
# Diff             float64
# Range            float64
# Diff %           float64
# Range %          float64
# VWAP %           float64
# 120 Days         float64
# 180 Days         float64
# 52 Weeks High    float64
# 52 Weeks Low     float64
# date              object
# dtype: object

# %%
df2['date']=pd.to_datetime(df2['date'])

# %%
df2=df2.sort_values(['Symbol','date'])

# %%
stock_df=df2[df2['Symbol']=='HPPL']

# %%
stock_df
# Out:
#       S.No Symbol  Conf.   Open   High    Low  Close    LTP  Close - LTP  \
# 7383    87   HPPL   39.1  460.0  466.0  458.5  466.0  466.0          0.0
# 7382    87   HPPL   39.1  460.0  466.0  458.5  466.0  466.0          0.0
# 7381    87   HPPL   39.1  460.0  466.0  458.5  466.0  466.0          0.0
# 7380    87   HPPL   39.1  460.0  466.0  458.5  466.0  466.0          0.0
# 7379    87   HPPL   39.1  460.0  466.0  458.5  466.0  466.0          0.0
# ...    ...    ...    ...    ...    ...    ...    ...    ...          ...
# 7307    93   HPPL      -  466.0  473.0  466.0  467.3  467.3          0.0
# 7306    90   HPPL      -  465.0  468.5  461.0  461.0  461.0          0.0
# 7305    90   HPPL  34.91  465.0  468.5  461.0  461.0  461.0          0.0
# 7304    90   HPPL  34.91  465.0  468.5  461.0  461.0  461.0          0.0
# 7303    98   HPPL      -  462.0  468.4  461.1  465.4  465.4          0.0
#
#       Close - LTP %  ...  Diff Range  Diff %  Range %  VWAP %  120 Days  \
# ...

# %%
df2['Daily_return']=df2.groupby('Symbol')['Close'].pct_change()

# %%
df2.to_csv("stock(oct-dec)1.csv",index=False)

# %%
df2['Daily_return'].max()
# Out:
# np.float64(0.10000000000000009)

# %%
df2.duplicated()
# Out:
# 80       False
# 79       False
# 78       False
# 77       False
# 76       False
#          ...
# 26220    False
# 26219    False
# 26218    False
# 26300    False
# 26299    False
# Length: 26301, dtype: bool

# %%
ret_df=df2.groupby('Symbol')['Daily_return'].mean().reset_index()
ret_df.columns=['Symbol','Return']

# %%
ret_df['Returns']
# Out:
# (array([  1.,   9., 371.,  11.,   3.,   1.,   1.,   3.,   0.,   2.]),
#  array([-0.0204545 , -0.01205364, -0.00365278,  0.00474807,  0.01314893,
#          0.02154979,  0.02995064,  0.0383515 ,  0.04675236,  0.05515322,
#          0.06355407]),
#  <BarContainer object of 10 artists>)

# %%
volatility1=(df2.groupby('Symbol')['Daily_return'].std().sort_values(ascending=False))

# %%
print(volatility1.head(30))
# Out:
# Symbol
# JHAPA       0.054982
# SAGAR       0.054742
# SAIL        0.053806
# SYPNL       0.050387
# BUNGAL      0.049257
# SWASTIK     0.049167
# MABEL       0.048013
# BANDIPUR    0.046322
# SAMAJ       0.040209
# PBLD86      0.039857
# DHEL        0.039641
# NIMBD90     0.033373
# SRBLD83     0.033253
# NRN         0.031742
# USLB        0.031110
# HIMSTAR     0.030005
# BEDC        0.029392
# BOKD86KA    0.028753
# SBID83      0.028542
# SBLD89      0.028489
# GBLBS       0.028020
# JBBD87      0.027945
# NBLD85      0.027408
# SGHC        0.027256
# NABBC       0.026544
# CIZBD86     0.026272
# HPPL        0.025884
# FMDBL       0.025418
# MKCL        0.025319
# SBLD2082    0.024988
# Name: Daily_return, dtype: float64

# %%
vol_df1=volatility.reset_index()
vol_df1.columns=['Symbol','Volatility']

# %%
vol_df1
# Out:
#      Symbol  Volatility
# 0     JHAPA    0.054982
# 1     SAGAR    0.054742
# 2      SAIL    0.053806
# 3     SYPNL    0.050387
# 4    BUNGAL    0.049257
# ..      ...         ...
# 406     NLO         NaN
# 407  SMATAP         NaN
# 408  SNMAPO         NaN
# 409  UAILPO         NaN
# 410   WNLBP         NaN
#
# [411 rows x 2 columns]

# %%
import os

# %%
os.

# %%
vol_df1['Volatility']=vol_df1['Volatility'].fillna(0)

# %%
ret_df['Sharpe_ratio'] = ret_df['Return'] / vol_df1['Volatility']

# %%
ret_df.isnull().sum()
# Out:
# Symbol           0
# Return           9
# Sharpe_ratio    11
# dtype: int64

# %%
plt.scatter(vol_df1['Volatility'],ret_df['Return'])

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --- ------------------------------------ 0.8/8.1 MB 6.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.1/8.1 MB 6.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 3.4/8.1 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.7/8.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.8/8.1 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.1/8.1 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 5.9 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    - -------------------------------------- 1.0/39.4 MB 6.1 MB/s eta 0:00:07
#    -- ------------------------------------- 2.4/39.4 MB 6.1 MB/s eta 0:00:07
#    --- ------------------------------------ 3.7/39.4 MB 6.1 MB/s eta 0:00:06
# ...

# %%
plt.hist(vol_df1['Volatility'])
# Out:
# (array([ 31.,  79., 172.,  76.,  31.,   9.,   2.,   3.,   4.,   4.]),
#  array([0.        , 0.00549815, 0.0109963 , 0.01649445, 0.02199261,
#         0.02749076, 0.03298891, 0.03848706, 0.04398521, 0.04948336,
#         0.05498152]),
#  <BarContainer object of 10 artists>)

# %%
import pandas as pd
import numpy as np

# %%
df3=pd.read_csv('merged.csv')

# %%
df3
# Out:
#      Symbol        Date   Open   High    Low   Close Percent Change  \
# 0       AHL  2025-12-22  555.0  557.0  545.1  550.20        -1.22 %
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00        -2.62 %
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00        -1.41 %
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20        -1.16 %
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00        -0.51 %
# ...     ...         ...    ...    ...    ...     ...            ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31        -0.47 %
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14        -1.48 %
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11         1.11 %
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44         1.07 %
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12         0.70 %
#
#          Volume Turn Over
# 0     12,467.00         -
# 1      9,937.00         -
# 2      9,929.00         -
# 3      7,844.00         -
# ...

# %%
df3.dtypes
# Out:
# Symbol             object
# Date               object
# Open              float64
# High              float64
# Low               float64
# Close             float64
# Percent Change     object
# Volume             object
# Turn Over          object
# dtype: object

# %%
df3['Percent Change']=(df3['Percent Change'].str.replace("%","",regex=False).str.strip().astype(float))

# %%
df3.isnull().sum()
# Out:
# Symbol            0
# Date              0
# Open              0
# High              0
# Low               0
# Close             0
# Percent Change    0
# Volume            0
# Turn Over         0
# dtype: int64

# %%
df3["Volume"] = pd.to_numeric(
    df3["Volume"]
    .astype(str)
    .replace("-", np.nan)
    .str.replace(",", "", regex=False)
    .str.replace("%", "", regex=False),
    errors="coerce"
)

# %%
df3.isnull().sum()
# Out:
# Symbol              0
# Date                0
# Open                0
# High                0
# Low                 0
# Close               0
# Percent Change      0
# Volume            814
# Turn Over           0
# dtype: int64

# %%
null=df3[df3.isnull().any(axis=1)]

# %%
null
# Out:
#      Symbol        Date        Open        High         Low       Close  \
# 536   BARUN  2025-11-27  335.942721  348.448687  335.083532  337.852029
# 537   BARUN  2025-11-26  327.446301  347.494033  327.446301  342.720764
# 538   BARUN  2025-11-25  318.186158  336.992840  318.186158  332.410501
# 539   BARUN  2025-11-24  338.806683  338.806683  324.582339  324.677804
# 540   BARUN  2025-11-23  333.937947  335.083532  327.637232  332.219570
# ...     ...         ...         ...         ...         ...         ...
# 9247   UPCL  2025-07-07  355.596330  366.972477  353.211009  354.311927
# 9248   UPCL  2025-07-06  367.064220  370.642202  361.467890  362.834862
# 9249   UPCL  2025-07-03  376.146789  376.146789  366.972477  367.513761
# 9250   UPCL  2025-07-02  383.394495  390.366972  372.477064  373.889908
# 9251   UPCL  2025-07-01  370.642202  384.770642  370.642202  383.357798
#
#       Percent Change  Volume Turn Over
# 536            -1.42     NaN         -
# ...

# %%
null.head(30)
# Out:
#     Symbol        Date        Open        High         Low       Close  \
# 536  BARUN  2025-11-27  335.942721  348.448687  335.083532  337.852029
# 537  BARUN  2025-11-26  327.446301  347.494033  327.446301  342.720764
# 538  BARUN  2025-11-25  318.186158  336.992840  318.186158  332.410501
# 539  BARUN  2025-11-24  338.806683  338.806683  324.582339  324.677804
# 540  BARUN  2025-11-23  333.937947  335.083532  327.637232  332.219570
# 541  BARUN  2025-11-20  329.355609  336.038186  317.899761  327.446301
# 542  BARUN  2025-11-19  333.174224  355.131265  326.396181  329.260143
# 543  BARUN  2025-11-18  322.577566  337.470167  320.763723  332.124105
# 544  BARUN  2025-11-17  316.945107  322.673031  312.171838  319.045346
# 545  BARUN  2025-11-16  324.582339  324.582339  310.835322  317.136038
# 546  BARUN  2025-11-13  330.310263  335.369928  321.718377  329.355609
# 547  BARUN  2025-11-12  315.035800  335.942721  315.035800  324.582339
# ...

# %%
def fill_nul(row,data,dataf):
    dataf.loc[row,'Volume']=data

# %%
df4=df3.drop(columns=['Volume','Turn Over'])

# %%
df4.dtypes
# Out:
# Symbol             object
# Date               object
# Open              float64
# High              float64
# Low               float64
# Close             float64
# Percent Change    float64
# dtype: object

# %%
df4.to_csv('newmerg.csv')

# %%
df4
# Out:
#      Symbol        Date   Open   High    Low   Close  Percent Change
# 0       AHL  2025-12-22  555.0  557.0  545.1  550.20           -1.22
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00           -2.62
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00           -1.41
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20           -1.16
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00           -0.51
# ...     ...         ...    ...    ...    ...     ...             ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31           -0.47
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14           -1.48
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11            1.11
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44            1.07
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12            0.70
#
# [9666 rows x 7 columns]

# %%
df4=df4.rename(columns={df4.columns[0]:'Symbol'})

# %%
df4
# Out:
#      Symbol        Date   Open   High    Low   Close  Percent Change
# 0       AHL  2025-12-22  555.0  557.0  545.1  550.20           -1.22
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00           -2.62
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00           -1.41
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20           -1.16
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00           -0.51
# ...     ...         ...    ...    ...    ...     ...             ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31           -0.47
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14           -1.48
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11            1.11
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44            1.07
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12            0.70
#
# [9666 rows x 7 columns]

# %%
df4['Date']=pd.to_datetime(df4['Date'])

# %%
df4
# Out:
#      Symbol       Date   Open   High    Low   Close  Percent Change
# 0       AHL 2025-12-22  555.0  557.0  545.1  550.20           -1.22
# 1       AHL 2025-12-21  565.0  570.0  556.0  557.00           -2.62
# 2       AHL 2025-12-18  583.0  583.0  571.3  572.00           -1.41
# 3       AHL 2025-12-17  577.1  598.0  577.1  580.20           -1.16
# 4       AHL 2025-12-16  595.0  595.0  580.0  587.00           -0.51
# ...     ...        ...    ...    ...    ...     ...             ...
# 9661  VLUCL 2025-07-07  600.0  604.0  591.0  594.31           -0.47
# 9662  VLUCL 2025-07-06  606.0  606.0  594.0  597.14           -1.48
# 9663  VLUCL 2025-07-03  599.0  611.0  594.0  606.11            1.11
# 9664  VLUCL 2025-07-02  593.0  606.0  591.0  599.44            1.07
# 9665  VLUCL 2025-07-01  590.0  601.8  588.0  593.12            0.70
#
# [9666 rows x 7 columns]

# %%
df4.dtypes
# Out:
# Symbol                    object
# Date              datetime64[ns]
# Open                     float64
# High                     float64
# Low                      float64
# Close                    float64
# Percent Change           float64
# dtype: object

# %%
df4.to_csv("newmerg2.csv",index=False)

# %%
pip install backtesting
# Out:
# ...
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/7.2 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.2 MB 2.9 MB/s eta 0:00:03
#    ------------- -------------------------- 2.4/7.2 MB 3.9 MB/s eta 0:00:02
#    -------------------- ------------------- 3.7/7.2 MB 4.4 MB/s eta 0:00:01
#    --------------------- ------------------ 3.9/7.2 MB 4.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.7/7.2 MB 4.2 MB/s eta 0:00:01
#    ------------------------------ --------- 5.5/7.2 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 6.8/7.2 MB 4.0 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 3.9 MB/s  0:00:01
# ...
#
#    ------------- -------------------------- 1/3 [bokeh]
#    ------------- -------------------------- 1/3 [bokeh]
#    ------------- -------------------------- 1/3 [bokeh]
# ...

# %%
from backtesting import Backtest,Strategy
from backtesting.lib import crossover
import pandas as pd
import numpy as np
df1=pd.read_csv("newmerg.csv")
df12=df1[df1['Symbol']=='HPPL']
def SMA(values, window):
    values = np.asarray(values)
    sma = np.full_like(values, np.nan, dtype=float)
    if window <= len(values):
        sma[window-1:] = np.convolve(values, np.ones(window)/window, mode='valid')
    return sma

# %%
df12.dtypes
# Out:
# Unnamed: 0          int64
# Symbol             object
# Date               object
# Open              float64
# High              float64
# Low               float64
# Close             float64
# Percent Change    float64
# dtype: object

# %%
import pandas as pd
from backtesting import Backtest, Strategy
from backtesting.lib import crossover

# Load CSV
df1 = pd.read_csv("newmerg.csv")
df12 = df1[df1['Symbol'] == 'HPPL'].copy()

# Ensure datetime index
df12['Date'] = pd.to_datetime(df12['Date'])
df12.set_index('Date', inplace=True)

# Keep only required columns
df12 = df12[['Open', 'High', 'Low', 'Close']].dropna()

# Define SMA
import numpy as np
def SMA(values, window):
    values = np.asarray(values, dtype=float)
    if len(values) < window:
        return np.full_like(values, np.nan)
    sma = np.convolve(values, np.ones(window)/window, mode='valid')
    return np.concatenate([np.full(window-1, np.nan), sma])

# Strategy
class SMACross(Strategy):
    fast = 5
    slow = 18

    def init(self):
        self.sma_fast = self.I(SMA, self.data.Close, self.fast)
        self.sma_slow = self.I(SMA, self.data.Close, self.slow)

    def next(self):
        if crossover(self.sma_fast, self.sma_slow):
            self.buy(size=0.1)
        elif crossover(self.sma_slow, self.sma_fast):
            self.sell(size=0.1)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2972\2679538185.py:41: UserWarning:
#
# Data index is not sorted in ascending order. Sorting.
# Backtest.run:   0%|          | 0/86 [00:00<?, ?bar/s]
# Start                     2025-07-01 00:00:00
# End                       2025-12-22 00:00:00
# Duration                    174 days 00:00:00
# Exposure Time [%]                    66.34615
# Equity Final [$]                    9986.6585
# Equity Peak [$]                     10093.087
# Commissions [$]                        3.8415
# Return [%]                           -0.13342
# Buy & Hold Return [%]               -11.45824
# Return (Ann.) [%]                    -0.46745
# Volatility (Ann.) [%]                 2.18508
# CAGR [%]                             -0.27966
# Sharpe Ratio                         -0.21393
# Sortino Ratio                        -0.27417
# Calmar Ratio                         -0.30871
# Alpha [%]                            -0.46647
# ...

# %%
bt = Backtest(df12, SMACross, cash=100_000, commission=0.001, finalize_trades=True)

stats = bt.optimize(
    fast=range(3, 21, 2),    # fast SMA 3,5,7,...19
    slow=range(10, 51, 5),   # slow SMA 10,15,20,...50
    maximize='Equity Final [$]',
    constraint=lambda p: p.slow > p.fast,
)

print(stats)
bt.plot()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_2972\1707105451.py:1: UserWarning:
#
# Data index is not sorted in ascending order. Sorting.
#
# C:\Users\hp\Desktop\project\Project-4-SEMESTER-\myenv\Lib\site-packages\backtesting\backtesting.py:1624: RuntimeWarning:
#
# If you want to use multi-process optimization with `multiprocessing.get_start_method() == 'spawn'` (e.g. on Windows),set `backtesting.Pool = multiprocessing.Pool` (or of the desired context) and hide `bt.optimize()` call behind a `if __name__ == '__main__'` guard. Currently using thread-based paralellism, which might be slightly slower for non-numpy / non-GIL-releasing code. See https://github.com/kernc/backtesting.py/issues/1256
# ...
# Backtest.run:   0%|          | 0/89 [00:00<?, ?bar/s]
# Start                     2025-07-01 00:00:00
# End                       2025-12-22 00:00:00
# Duration                    174 days 00:00:00
# Exposure Time [%]                    75.96154
# Equity Final [$]                  100492.7719
# ...
