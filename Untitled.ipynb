# %%
import pandas as pd
import os
import numpy as np

# %%
folder_path='data'
all_files=os.listdir(folder_path)

# %%
dfs=[]
for file in all_files:
    if file.endswith(".csv"):
        file_path=os.path.join(folder_path,file)
        df=pd.read_csv(file_path)
        dfs.append(df)


merge_df=pd.concat(dfs,ignore_index=True)
merge_df.to_csv("merged.csv",index=False)

# %%
df2=pd.read_csv('merged.csv')

# %%
df2
# Out:
#      Symbol        Date   Open   High    Low   Close Percent Change  \
# 0       AHL  2025-12-22  555.0  557.0  545.1  550.20        -1.22 %
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00        -2.62 %
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00        -1.41 %
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20        -1.16 %
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00        -0.51 %
# ...     ...         ...    ...    ...    ...     ...            ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31        -0.47 %
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14        -1.48 %
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11         1.11 %
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44         1.07 %
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12         0.70 %
#
#          Volume Turn Over
# 0     12,467.00         -
# 1      9,937.00         -
# 2      9,929.00         -
# 3      7,844.00         -
# 4     14,683.00         -
# ...         ...       ...
# 9661   4,338.00         -
# 9662   6,390.00         -
# 9663  11,920.00         -
# 9664   9,190.00         -
# 9665  13,714.00         -
#
# [9666 rows x 9 columns]

# %%
df2['Return']=df2['Close'].pct_change()

# %%
df2
# Out:
#      Symbol        Date   Open   High    Low   Close Percent Change  \
# 0       AHL  2025-12-22  555.0  557.0  545.1  550.20        -1.22 %
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00        -2.62 %
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00        -1.41 %
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20        -1.16 %
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00        -0.51 %
# ...     ...         ...    ...    ...    ...     ...            ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31        -0.47 %
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14        -1.48 %
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11         1.11 %
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44         1.07 %
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12         0.70 %
#
#          Volume Turn Over    Return
# 0     12,467.00         -       NaN
# 1      9,937.00         -  0.012359
# 2      9,929.00         -  0.026930
# 3      7,844.00         -  0.014336
# 4     14,683.00         -  0.011720
# ...         ...       ...       ...
# 9661   4,338.00         -  0.003631
# 9662   6,390.00         -  0.004762
# 9663  11,920.00         -  0.015022
# 9664   9,190.00         - -0.011005
# 9665  13,714.00         - -0.010543
#
# [9666 rows x 10 columns]

# %%
df2.dropna()
# Out:
#      Symbol        Date   Open   High    Low   Close Percent Change  \
# 1       AHL  2025-12-21  565.0  570.0  556.0  557.00        -2.62 %
# 2       AHL  2025-12-18  583.0  583.0  571.3  572.00        -1.41 %
# 3       AHL  2025-12-17  577.1  598.0  577.1  580.20        -1.16 %
# 4       AHL  2025-12-16  595.0  595.0  580.0  587.00        -0.51 %
# 5       AHL  2025-12-15  583.1  596.0  583.1  590.00        -0.82 %
# ...     ...         ...    ...    ...    ...     ...            ...
# 9661  VLUCL  2025-07-07  600.0  604.0  591.0  594.31        -0.47 %
# 9662  VLUCL  2025-07-06  606.0  606.0  594.0  597.14        -1.48 %
# 9663  VLUCL  2025-07-03  599.0  611.0  594.0  606.11         1.11 %
# 9664  VLUCL  2025-07-02  593.0  606.0  591.0  599.44         1.07 %
# 9665  VLUCL  2025-07-01  590.0  601.8  588.0  593.12         0.70 %
#
#          Volume Turn Over    Return
# 1      9,937.00         -  0.012359
# 2      9,929.00         -  0.026930
# 3      7,844.00         -  0.014336
# 4     14,683.00         -  0.011720
# 5      7,165.00         -  0.005111
# ...         ...       ...       ...
# 9661   4,338.00         -  0.003631
# 9662   6,390.00         -  0.004762
# 9663  11,920.00         -  0.015022
# 9664   9,190.00         - -0.011005
# 9665  13,714.00         - -0.010543
#
# [9665 rows x 10 columns]

# %%
volatility=(df2.groupby('Symbol')['Return'].std().sort_values(ascending=False))

# %%
print(volatility.head(10))
# Out:
# Symbol
# KBSH       0.408272
# MABEL      0.393386
# RURU       0.174633
# TAMOR      0.160116
# HIMSTAR    0.143329
# BHPL       0.140645
# IHL        0.134838
# USHEC      0.132850
# SMH        0.130475
# KPCL       0.117310
# Name: Return, dtype: float64

# %%
vol_df1=volatility.reset_index()
vol_df1.columns=['Symbol','Volatility']

# %%
vol_df1
# Out:
#      Symbol  Volatility
# 0      KBSH    0.408272
# 1     MABEL    0.393386
# 2      RURU    0.174633
# 3     TAMOR    0.160116
# 4   HIMSTAR    0.143329
# ..      ...         ...
# 91      GLH    0.020610
# 92      SPC    0.020599
# 93     RAWA    0.019346
# 94      API    0.019283
# 95     UMRH    0.016880
#
# [96 rows x 2 columns]

# %%
average_return=(df2.groupby('Symbol')['Return'].mean().sort_values(ascending=False))

# %%
ret_df1=average_return.reset_index()
ret_df1.columns=['Symbol','Average_Return']

# %%
ret_df1
# Out:
#     Symbol  Average_Return
# 0    MABEL        0.047495
# 1     KBSH        0.040777
# 2     RURU        0.017193
# 3    TAMOR        0.017154
# 4     BHPL        0.016944
# ..     ...             ...
# 91    SSHL       -0.006363
# 92    KKHC       -0.006705
# 93    DHEL       -0.010133
# 94    BHCL       -0.010905
# 95  BUNGAL       -0.027225
#
# [96 rows x 2 columns]

# %%
merged_df=pd.merge(vol_df1,ret_df1,on='Symbol')

# %%
merged_df
# Out:
#      Symbol  Volatility  Average_Return
# 0      KBSH    0.408272        0.040777
# 1     MABEL    0.393386        0.047495
# 2      RURU    0.174633        0.017193
# 3     TAMOR    0.160116        0.017154
# 4   HIMSTAR    0.143329        0.000315
# ..      ...         ...             ...
# 91      GLH    0.020610        0.001071
# 92      SPC    0.020599        0.000083
# 93     RAWA    0.019346        0.000090
# 94      API    0.019283        0.001079
# 95     UMRH    0.016880        0.000516
#
# [96 rows x 3 columns]

# %%
merged_df['sharpe_ratio_daily']=merged_df['Average_Return']/merged_df['Volatility']

# %%
merged_df['sharpe_ratio_anuually']=merged_df['sharpe_ratio_daily'] *np.sqrt(252)

# %%
merged_df
# Out:
#      Symbol  Volatility  Average_Return  sharpe_ratio_daily  \
# 0      KBSH    0.408272        0.040777            0.099876
# 1     MABEL    0.393386        0.047495            0.120733
# 2      RURU    0.174633        0.017193            0.098450
# 3     TAMOR    0.160116        0.017154            0.107133
# 4   HIMSTAR    0.143329        0.000315            0.002199
# ..      ...         ...             ...                 ...
# 91      GLH    0.020610        0.001071            0.051975
# 92      SPC    0.020599        0.000083            0.004017
# 93     RAWA    0.019346        0.000090            0.004664
# 94      API    0.019283        0.001079            0.055956
# 95     UMRH    0.016880        0.000516            0.030579
#
#     sharpe_ratio_anuually
# 0                1.585488
# 1                1.916574
# 2                1.562853
# 3                1.700681
# 4                0.034909
# ..                    ...
# 91               0.825071
# 92               0.063762
# 93               0.074043
# 94               0.888267
# 95               0.485419
#
# [96 rows x 5 columns]

# %%
merged_df.head(15)
# Out:
#      Symbol  Volatility  Average_Return  sharpe_ratio_daily  \
# 0      KBSH    0.408272        0.040777            0.099876
# 1     MABEL    0.393386        0.047495            0.120733
# 2      RURU    0.174633        0.017193            0.098450
# 3     TAMOR    0.160116        0.017154            0.107133
# 4   HIMSTAR    0.143329        0.000315            0.002199
# 5      BHPL    0.140645        0.016944            0.120477
# 6       IHL    0.134838        0.012626            0.093634
# 7     USHEC    0.132850        0.012398            0.093323
# 8       SMH    0.130475        0.013909            0.106601
# 9      KPCL    0.117310        0.011857            0.101070
# 10     USHL    0.099380        0.006707            0.067487
# 11      GVL    0.092143        0.008237            0.089396
# 12     KKHC    0.091298       -0.006705           -0.073444
# 13     SHPC    0.086299        0.010024            0.116149
# 14     MKHL    0.085810        0.007615            0.088742
#
#     sharpe_ratio_anuually
# 0                1.585488
# 1                1.916574
# 2                1.562853
# 3                1.700681
# 4                0.034909
# 5                1.912511
# 6                1.486401
# 7                1.481460
# 8                1.692245
# 9                1.604439
# 10               1.071326
# 11               1.419121
# 12              -1.165884
# 13               1.843813
# 14               1.408743

# %%
merged_df.to_csv('hydro_return.csv',index=True)
